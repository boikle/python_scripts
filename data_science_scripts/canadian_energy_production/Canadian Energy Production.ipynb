# %% [markdown]
# # Canadian Energy Production Analysis:
#
# Data Source: Statistics Canada.  [Table  25-10-0015-01   Electric power generation, monthly generation by type of electricity](https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=2510001501)

# %%
import pandas as pd

data_source = 'data/25100015-eng/25100015.csv'
energy_data = pd.read_csv(data_source)

energy_data.head()
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   REF_DATE     GEO           DGUID              Class of electricity producer  \
# 0  2008-01  Canada  2016A000011124  Total all classes of electricity producer
# 1  2008-01  Canada  2016A000011124  Total all classes of electricity producer
# 2  2008-01  Canada  2016A000011124  Total all classes of electricity producer
# 3  2008-01  Canada  2016A000011124  Total all classes of electricity producer
# 4  2008-01  Canada  2016A000011124  Total all classes of electricity producer
#
#               Type of electricity generation             UOM  UOM_ID  \
# 0  Total all types of electricity generation  Megawatt hours     210
# 1                          Hydraulic turbine  Megawatt hours     210
# 2                 Conventional steam turbine  Megawatt hours     210
# 3                      Nuclear steam turbine  Megawatt hours     210
# 4                Internal combustion turbine  Megawatt hours     210
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE       VALUE STATUS SYMBOL  \
# 0        units           0  v44174609      1.1.1  59082501.0    NaN    NaN
# 1        units           0  v44174610      1.1.2  36647695.0    NaN    NaN
# 2        units           0  v44174611      1.1.3  11021441.0    NaN    NaN
# 3        units           0  v44174612      1.1.4   8963878.0    NaN    NaN
# 4        units           0  v44174613      1.1.5    105643.0    NaN    NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0
